# %%
from src.output_visualization.InteractiveWindowSlider import InteractiveWindow

# %%
image_path = r"C:\Users\cernil\OneDrive - Y Soft Corporation a.s\betapresentation_visualisation\outputs\classification\1classification.png"
InteractiveWindow([image_path])
